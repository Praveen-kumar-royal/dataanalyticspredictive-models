# %%
# Import functions from Python script
from capstone_script import load_data, explore_data, preprocess_data, train_model, evaluate_model

# %%
# Load data
data = load_data('adult.csv')

# %%
# Explore data
data_cleaned = explore_data(data)
# Out:
# Head of the dataset:
#    age  fnlwgt  education.num  capital.gain  capital.loss  hours.per.week  \
# 1   82  132870              9             0          4356              18
# 3   54  140359              4             0          3900              40
# 4   41  264663             10             0          3900              40
# 5   34  216864              9             0          3770              45
# 6   38  150601              6             0          3770              40
#
#    workclass_Local-gov  workclass_Private  workclass_Self-emp-inc  \
# 1                False               True                   False
# 3                False               True                   False
# 4                False               True                   False
# 5                False               True                   False
# 6                False               True                   False
#
#    workclass_Self-emp-not-inc  ...  native.country_Puerto-Rico  \
# ...

# %%
# Preprocess data
X_train, X_test, y_train, y_test = preprocess_data(data_cleaned)

# %%
# Train models
logistic_model, knn_model, dt_model = train_model(X_train, y_train)

# %%
# Evaluate models
evaluate_model(logistic_model, X_test, y_test)
evaluate_model(knn_model, X_test, y_test)
evaluate_model(dt_model, X_test, y_test)
# Out:
# logisticregression Model:
# Accuracy Score: 0.8426327193932828
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.88      0.93      0.90      2934
#         True       0.66      0.49      0.56       758
#
#     accuracy                           0.84      3692
#    macro avg       0.77      0.71      0.73      3692
# weighted avg       0.83      0.84      0.83      3692
#
#
# Confusion Matrix:
# [[2740  194]
#  [ 387  371]]
# kneighborsclassifier Model:
# Accuracy Score: 0.8201516793066089
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.88      0.90      0.89      2934
#         True       0.57      0.50      0.54       758
#
#     accuracy                           0.82      3692
#    macro avg       0.72      0.70      0.71      3692
# weighted avg       0.81      0.82      0.82      3692
#
#
# Confusion Matrix:
# [[2646  288]
#  [ 376  382]]
# ...
